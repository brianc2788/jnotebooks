# %% [markdown]
# <!--
# Jupyter Notebook (Python3 & Markdown), ipykernel
# ---
# Title, Description, Information.
# -->
# # <u>WiFi Wardrive Analysis</u> #
# *Analysis of local wifi access points (APs) and devices.
# Data obtained with **Wigle WiFi Wardrive** for **Android**.*
#
# ### <u>*Description*</u> ###
#
# **WigleWifi Wardrive** scans wifi, bluetooth, and mobile bands.
# It also uses GPS & Signal Strength measurements to determine
# the location of device broadcasts as well as typical WiFi
# config (type of encryption, BSSID, HW address, etc).*
#
# Authored by [brianc2788@gmail.com](mailto:brianc2788@gmail.com)
# *&copy; 2002 - Some rights reserved.*
#
# ---

# %%
import os,sys
import pandas as pd

csvpath = os.path.join('/','home','userone','netanalysis','wigle','wigle_may17.csv')
dframe = pd.read_csv(csvpath)

# %%
dframe.describe()
# Out:
#               WigleWifi-1.4 appRelease=2.64 model=A502DL      release=8.1.0  \
# count                 22276           22276        22276              22276
# unique                 4673              41           98               3762
# top     1969-12-31 19:00:00               0          -99  42.85698166666666
# freq                    118           10997         1463                179
#
#        device=U50A_PLUS_TF display=Android O        board=A502DL brand=TCL
# count                22276             22276               22276     22274
# unique                3238               603                  73         6
# top             -78.828755             180.6  2.5999999046325684       BLE
# freq                   186               209                1874     12514

# %%
dframe.head(10)
# Out:
#                                                                  WigleWifi-1.4  \
# MAC                   SSID               AuthMode                    FirstSeen
# 311480_17922_17961228 Verizon Wireless   LTE;us            2022-05-05 09:34:04
#                                          LTE;us            2022-05-05 09:34:04
# d9:73:3b:3d:ca:46     NaN                Misc              2022-05-05 09:34:04
# d3:cd:6a:31:94:f0     NaN                Misc              2022-05-05 09:34:04
# 71:32:f8:8a:19:0c     NaN                Uncategorized;10  2022-05-05 09:34:04
# 24:fc:e5:c4:1f:9f     NaN                Misc              2022-05-05 09:34:04
# 11:02:56:e1:a2:12     NaN                Uncategorized;10  2022-05-05 09:34:04
# d0:d2:b0:7c:67:bb     NaN                Misc              2022-05-05 09:34:04
# a4:c1:38:a3:a0:a8     ihoment_H6054_A0A8 Misc              2022-05-05 09:34:04
#
#                                                           appRelease=2.64  \
# ...
